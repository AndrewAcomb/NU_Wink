# %%
import requests
import json
params = {
  'key': 'JC3v77yRGJzdrHNn'
}
response = requests.get('http://api.asg.northwestern.edu/buildings/?key=YOUR_KEY'
, params=params)

json_data = json.loads(response.text)
json_data2 = json.dumps(response.json(), sort_keys=True, indent=4)

# calling response.json() returns the response as a Python dictionary or list
print (json_data2)
# Out:
# [
#     {
#         "id": 1,
#         "lat": 42.0491174,
#         "lon": -87.6759464,
#         "name": "1801 Hinman Ave",
#         "nu_maps_link": "http://maps.northwestern.edu/#latlngz=42.049%2C-87.675%2C17&lookupid=70"
#     },
#     {
#         "id": 2,
#         "lat": 42.0495785,
#         "lon": -87.6780466,
#         "name": "1808 Chicago Ave (SOCIOL)",
#         "nu_maps_link": "http://maps.northwestern.edu/#latlngz=42.05%2C-87.678%2C17&lookupid=202"
#     },
#     {
#         "id": 3,
#         "lat": 42.0495756,
#         "lon": -87.6780088,
#         "name": "1809 Chicago (Hardy House)",
#         "nu_maps_link": "http://maps.northwestern.edu/#latlngz=42.05%2C-87.677%2C17&lookupid=650"
#     },
#     {
#         "id": 4,
#         "lat": 42.0496147,
#         "lon": -87.6760988,
#         "name": "1810 Hinman Ave (ANTHRO)",
#         "nu_maps_link": "http://maps.northwestern.edu/#latlngz=42.049%2C-87.677%2C17&lookupid=71"
#     },
#     {
#         "id": 5,
# ...
